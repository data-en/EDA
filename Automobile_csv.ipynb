# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
df = pd.read_csv('/content/drive/MyDrive/Automobile.csv')

# %%
df.head()
# Out:
#                         name   mpg  cylinders  displacement  horsepower  \
# 0  chevrolet chevelle malibu  18.0          8         307.0       130.0
# 1          buick skylark 320  15.0          8         350.0       165.0
# 2         plymouth satellite  18.0          8         318.0       150.0
# 3              amc rebel sst  16.0          8         304.0       150.0
# 4                ford torino  17.0          8         302.0       140.0
#
#    weight  acceleration  model_year origin
# 0    3504          12.0          70    usa
# 1    3693          11.5          70    usa
# 2    3436          11.0          70    usa
# 3    3433          12.0          70    usa
# 4    3449          10.5          70    usa

# %%
df.tail()
# mpg - the average number of miles a vehicle can drive on one gallon of fuel
# horsepower - Horsepower is a measurement used to calculate how quickly the force is produced from a vehicle's engine.
# Out:
#                 name   mpg  cylinders  displacement  horsepower  weight  \
# 393  ford mustang gl  27.0          4         140.0        86.0    2790
# 394        vw pickup  44.0          4          97.0        52.0    2130
# 395    dodge rampage  32.0          4         135.0        84.0    2295
# 396      ford ranger  28.0          4         120.0        79.0    2625
# 397       chevy s-10  31.0          4         119.0        82.0    2720
#
#      acceleration  model_year  origin
# 393          15.6          82     usa
# 394          24.6          82  europe
# 395          11.6          82     usa
# 396          18.6          82     usa
# 397          19.4          82     usa

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 398 entries, 0 to 397
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   name          398 non-null    object
#  1   mpg           398 non-null    float64
#  2   cylinders     398 non-null    int64
#  3   displacement  398 non-null    float64
#  4   horsepower    392 non-null    float64
#  5   weight        398 non-null    int64
#  6   acceleration  398 non-null    float64
#  7   model_year    398 non-null    int64
#  8   origin        398 non-null    object
# dtypes: float64(4), int64(3), object(2)
# memory usage: 28.1+ KB

# %%
df.describe()
# Out:
#               mpg   cylinders  displacement  horsepower       weight  \
# count  398.000000  398.000000    398.000000  392.000000   398.000000
# mean    23.514573    5.454774    193.425879  104.469388  2970.424623
# std      7.815984    1.701004    104.269838   38.491160   846.841774
# min      9.000000    3.000000     68.000000   46.000000  1613.000000
# 25%     17.500000    4.000000    104.250000   75.000000  2223.750000
# 50%     23.000000    4.000000    148.500000   93.500000  2803.500000
# 75%     29.000000    8.000000    262.000000  126.000000  3608.000000
# max     46.600000    8.000000    455.000000  230.000000  5140.000000
#
#        acceleration  model_year
# count    398.000000  398.000000
# mean      15.568090   76.010050
# std        2.757689    3.697627
# min        8.000000   70.000000
# 25%       13.825000   73.000000
# 50%       15.500000   76.000000
# 75%       17.175000   79.000000
# max       24.800000   82.000000

# %%
df.shape
# Out:
# (398, 9)

# %%
df.index
# Out:
# RangeIndex(start=0, stop=398, step=1)

# %%
df.columns
# Out:
# Index(['name', 'mpg', 'cylinders', 'displacement', 'horsepower', 'weight',
#        'acceleration', 'model_year', 'origin'],
#       dtype='object')

# %%
df.rename(columns={'mpg':'MPG','origin':'Origin','name':'Name','cylinders':'Cylinders','displacement':'Displacement','horsepower':'Horsepower','weight':'Weight','acceleration':'Acceleration',},inplace=True)

# %%
df.columns
# Out:
# Index(['Name', 'MPG', 'Cylinders', 'Displacement', 'Horsepower', 'Weight',
#        'Acceleration', 'model_year', 'Origin'],
#       dtype='object')

# %%
df.rename(columns={'model_year':'ModelYear'},inplace=True)

# %%
df.columns
# Out:
# Index(['Name', 'MPG', 'Cylinders', 'Displacement', 'Horsepower', 'Weight',
#        'Acceleration', 'ModelYear', 'Origin'],
#       dtype='object')

# %%
df.drop_duplicates(inplace=True)

# %%
df.shape
# Out:
# (398, 9)

# %%
df.isnull().sum()
# Out:
# name            0
# mpg             0
# cylinders       0
# displacement    0
# horsepower      6
# weight          0
# acceleration    0
# model_year      0
# origin          0
# dtype: int64

# %%
df[df['horsepower'].isnull()]
# Out:
#                      name   mpg  cylinders  displacement  horsepower  weight  \
# 32             ford pinto  25.0          4          98.0         NaN    2046
# 126         ford maverick  21.0          6         200.0         NaN    2875
# 330  renault lecar deluxe  40.9          4          85.0         NaN    1835
# 336    ford mustang cobra  23.6          4         140.0         NaN    2905
# 354           renault 18i  34.5          4         100.0         NaN    2320
# 374        amc concord dl  23.0          4         151.0         NaN    3035
#
#      acceleration  model_year  origin
# 32           19.0          71     usa
# 126          17.0          74     usa
# 330          17.3          80  europe
# 336          14.3          80     usa
# 354          15.8          81  europe
# 374          20.5          82     usa

# %%
df['horsepower'].unique()
# Out:
# array([130., 165., 150., 140., 198., 220., 215., 225., 190., 170., 160.,
#         95.,  97.,  85.,  88.,  46.,  87.,  90., 113., 200., 210., 193.,
#         nan, 100., 105., 175., 153., 180., 110.,  72.,  86.,  70.,  76.,
#         65.,  69.,  60.,  80.,  54., 208., 155., 112.,  92., 145., 137.,
#        158., 167.,  94., 107., 230.,  49.,  75.,  91., 122.,  67.,  83.,
#         78.,  52.,  61.,  93., 148., 129.,  96.,  71.,  98., 115.,  53.,
#         81.,  79., 120., 152., 102., 108.,  68.,  58., 149.,  89.,  63.,
#         48.,  66., 139., 103., 125., 133., 138., 135., 142.,  77.,  62.,
#        132.,  84.,  64.,  74., 116.,  82.])

# %%
df['horsepower'].mode()
# Out:
# 0    150.0
# Name: horsepower, dtype: float64

# %%
df['horsepower'].median()
# Out:
# 93.5

# %%
df['horsepower'] = df['horsepower'].fillna(93.5)

# %%
df['horsepower'].isnull().sum()
# Out:
# 0

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.graph_objects as go

# %%
plt.figure(figsize=(6,2))
plt.scatter(df.MPG,df.Horsepower,marker='.',c='#33FF9C',alpha=0.9) # c = html color codes,alpha = intensity of colour(dark or faint)
plt.xlabel('X-axis')
plt.ylabel('Y-axis')
plt.title('MPG vs Horsepower')
plt.grid()

# %%
df.columns
# Out:
# Index(['Name', 'MPG', 'Cylinders', 'Displacement', 'Horsepower', 'Weight',
#        'Acceleration', 'ModelYear', 'Origin'],
#       dtype='object')

# %%
sns.scatterplot(x=df.Displacement,y=df.Acceleration,alpha=0.9)
# Out:
# <Axes: xlabel='Displacement', ylabel='Acceleration'>

# %%
sns.histplot(df.Weight)
# Out:
# <Axes: xlabel='Weight', ylabel='Count'>

# %%
import pandas as pd
df['Horsepower'].value_counts()
# Out:
# 150.0    22
# 90.0     20
# 88.0     19
# 110.0    18
# 100.0    17
#          ..
# 61.0      1
# 93.0      1
# 148.0     1
# 152.0     1
# 82.0      1
# Name: Horsepower, Length: 93, dtype: int64

# %%
sns.catplot(x='Weight',y='Displacement',data=df)

# %%
df.head()
# Out:
#                         Name   MPG  Cylinders  Displacement  Horsepower  \
# 0  chevrolet chevelle malibu  18.0          8         307.0       130.0
# 1          buick skylark 320  15.0          8         350.0       165.0
# 2         plymouth satellite  18.0          8         318.0       150.0
# 3              amc rebel sst  16.0          8         304.0       150.0
# 4                ford torino  17.0          8         302.0       140.0
#
#    Weight  Acceleration  ModelYear Origin
# 0    3504          12.0         70    usa
# 1    3693          11.5         70    usa
# 2    3436          11.0         70    usa
# 3    3433          12.0         70    usa
# 4    3449          10.5         70    usa

# %%
sns.pairplot(data=df)

# %%
sns.jointplot(x=df.ModelYear,y=df.Weight)

# %%
sns.violinplot(data=df,x=df.ModelYear,y=df.Horsepower)
# Out:
# <Axes: xlabel='ModelYear', ylabel='Horsepower'>

# %%
sns.kdeplot(data=df,x=df.ModelYear,y=df.Acceleration)
# Out:
# <Axes: xlabel='ModelYear', ylabel='Acceleration'>

# %%
sns.histplot(data=df,x=df.ModelYear,y=df.Acceleration)
# Out:
# <Axes: xlabel='ModelYear', ylabel='Acceleration'>

# %%
sns.boxplot(data=df,x=df.ModelYear,y=df.Acceleration)
# Out:
# <Axes: xlabel='ModelYear', ylabel='Acceleration'>
